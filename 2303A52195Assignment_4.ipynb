# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash-Gaju/AIML-2303A52195-/blob/main/2303A52195Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_read = pd.read_csv('/content/train.csv')
print(data_read)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y = data_read['price_range']
print(y)
print(y.shape)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64
# (2000,)

# %%
x = data_read.drop('price_range', axis=1)
print(x)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
print(data_read.isnull().sum())
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
xx = (x - x.min())/(x.max()-x.min())
print(xx)
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xx, y, test_size=0.2, random_state=42)

# %%
x_train,x_test,y_train,y_test = train_test_split(xx,y,test_size=0.2,random_state=40)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1239       0.493654   0.0         0.44       0.0  0.000000     0.0
# 426        0.460254   1.0         0.68       1.0  0.473684     0.0
# 1249       0.002004   1.0         0.92       1.0  0.105263     0.0
# 727        0.727455   0.0         0.04       1.0  0.000000     0.0
# 800        0.626587   0.0         0.16       0.0  0.631579     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1016       0.033400   1.0         0.92       0.0  0.000000     1.0
# 165        0.010688   0.0         0.36       1.0  0.157895     1.0
# 7          0.970608   0.0         0.00       1.0  0.000000     0.0
# 219        0.701403   0.0         0.24       0.0  0.210526     0.0
# 1350       0.599198   0.0         0.44       1.0  0.421053     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 1239    0.596774  0.000000   0.550000  0.142857  0.45   0.770918  0.838451
# ...

# %%
data_housing = pd.read_csv('//content/housing.csv.zip')
print(data_housing)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y = data_housing['ocean_proximity']
print(y)
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %%
x = data_housing.drop('ocean_proximity', axis=1)
print(x)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
xx_train, xx_test, yy_train, yy_test = train_test_split(x, y, test_size=0.2, random_state=40)
print(xx_train)
print(xx_test)
print(yy_train)
print(yy_test)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9226     -120.04     36.93                11.0       3606.0           699.0
# 11826    -121.04     39.00                21.0       4059.0           730.0
# 4553     -118.24     34.06                33.0        390.0           199.0
# 10787    -117.92     33.64                25.0       2224.0           580.0
# 4104     -118.35     34.13                39.0       1610.0           278.0
# ...          ...       ...                 ...          ...             ...
# 11532    -118.09     33.77                26.0       5359.0          1508.0
# 16065    -122.48     37.75                49.0       2203.0           407.0
# 14501    -117.23     32.86                16.0       1200.0           468.0
# 14555    -117.13     32.96                15.0       2267.0           292.0
# 11590    -118.01     33.78                26.0       2343.0           377.0
#
# ...
