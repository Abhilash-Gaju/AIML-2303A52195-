# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash-Gaju/AIML-2303A52195-/blob/main/2303A52195_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv("/content/archive (2).zip")
print(d.head(1))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY

# %%
columns = ['latitude','total_rooms','housing_median_age','total_bedrooms']
answer = d[columns]

mle_params = {}

# %%
import numpy as np
for i in columns:
  mean = np.mean(d[i])
  variance = np.var(d[i])

  mle_params[i]={'mean':mean,'variance':variance}
  print(i,mean)
  print(i,variance)
# Out:
# latitude 35.63186143410853
# latitude 4.562071602892517
# total_rooms 2635.7630813953488
# total_rooms 4759214.512668024
# housing_median_age 28.639486434108527
# housing_median_age 158.38858617035862
# total_bedrooms 537.8705525375618
# total_bedrooms 177556.6871536956

# %%
import numpy as np
n=len(d['latitude'])
print(n)
print(-n/2*np.log(2*np.pi)-n/2*np.log(np.var(d['latitude']))-1/(2*np.var(d['latitude']))*(50-np.mean(d['latitude']))**2)
print(-n/2*np.log(2*np.pi)-n/2*np.log(np.var(d['latitude']))-1/(2*np.var(d['latitude']))*(75-np.mean(d['latitude']))**2)
print(-n/2*np.log(2*np.pi)-n/2*np.log(np.var(d['latitude']))-1/(2*np.var(d['latitude']))*(80-np.mean(d['latitude']))**2)
# Out:
# 20640
# -34652.97415930701
# -34800.210661189485
# -34846.097861358976

# %%
columns = ['latitude','total_rooms','housing_median_age','total_bedrooms']
import matplotlib.pyplot as plt
plt.hist(d['latitude'],5)
# Out:
# (array([10783.,  1221.,  6004.,  2230.,   402.]),
#  array([32.54 , 34.422, 36.304, 38.186, 40.068, 41.95 ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(d['latitude'],10)
# Out:
# (array([1796., 8987.,  747.,  474., 1292., 4712., 1740.,  490.,  324.,
#           78.]),
#  array([32.54 , 33.481, 34.422, 35.363, 36.304, 37.245, 38.186, 39.127,
#         40.068, 41.009, 41.95 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['latitude'],15)
# Out:
# (array([1536., 1740., 7507.,  517.,  461.,  243.,  920., 1760., 3324.,
#         1471.,  532.,  227.,  216.,  134.,   52.]),
#  array([32.54      , 33.16733333, 33.79466667, 34.422     , 35.04933333,
#         35.67666667, 36.304     , 36.93133333, 37.55866667, 38.186     ,
#         38.81333333, 39.44066667, 40.068     , 40.69533333, 41.32266667,
#         41.95      ]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(d['latitude'],20)
# Out:
# (array([1333.,  463., 3710., 5277.,  437.,  310.,  261.,  213.,  624.,
#          668., 2187., 2525., 1146.,  594.,  328.,  162.,  121.,  203.,
#           35.,   43.]),
#  array([32.54  , 33.0105, 33.481 , 33.9515, 34.422 , 34.8925, 35.363 ,
#         35.8335, 36.304 , 36.7745, 37.245 , 37.7155, 38.186 , 38.6565,
#         39.127 , 39.5975, 40.068 , 40.5385, 41.009 , 41.4795, 41.95  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(d['total_rooms'],5)
# Out:
# (array([2.0083e+04, 4.7500e+02, 6.5000e+01, 1.3000e+01, 4.0000e+00]),
#  array([2.00000e+00, 7.86560e+03, 1.57292e+04, 2.35928e+04, 3.14564e+04,
#         3.93200e+04]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(d['total_rooms'],10)
# Out:
# (array([1.7525e+04, 2.5580e+03, 3.7200e+02, 1.0300e+02, 4.9000e+01,
#         1.6000e+01, 7.0000e+00, 6.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([2.00000e+00, 3.93380e+03, 7.86560e+03, 1.17974e+04, 1.57292e+04,
#         1.96610e+04, 2.35928e+04, 2.75246e+04, 3.14564e+04, 3.53882e+04,
#         3.93200e+04]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['total_rooms'],15)
# Out:
# (array([1.3247e+04, 5.8160e+03, 1.0200e+03, 3.1200e+02, 1.0500e+02,
#         5.8000e+01, 3.8000e+01, 1.8000e+01, 9.0000e+00, 6.0000e+00,
#         4.0000e+00, 3.0000e+00, 2.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([2.00000e+00, 2.62320e+03, 5.24440e+03, 7.86560e+03, 1.04868e+04,
#         1.31080e+04, 1.57292e+04, 1.83504e+04, 2.09716e+04, 2.35928e+04,
#         2.62140e+04, 2.88352e+04, 3.14564e+04, 3.40776e+04, 3.66988e+04,
#         3.93200e+04]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(d['total_rooms'],20)
# Out:
# (array([9.172e+03, 8.353e+03, 1.934e+03, 6.240e+02, 2.510e+02, 1.210e+02,
#         6.300e+01, 4.000e+01, 3.200e+01, 1.700e+01, 1.200e+01, 4.000e+00,
#         5.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00]),
#  array([2.00000e+00, 1.96790e+03, 3.93380e+03, 5.89970e+03, 7.86560e+03,
#         9.83150e+03, 1.17974e+04, 1.37633e+04, 1.57292e+04, 1.76951e+04,
#         1.96610e+04, 2.16269e+04, 2.35928e+04, 2.55587e+04, 2.75246e+04,
#         2.94905e+04, 3.14564e+04, 3.34223e+04, 3.53882e+04, 3.73541e+04,
#         3.93200e+04]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(d['housing_median_age'],5)
# Out:
# (array([1823., 4916., 4864., 5455., 3582.]),
#  array([ 1. , 11.2, 21.4, 31.6, 41.8, 52. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(d['housing_median_age'],10)
# Out:
# (array([ 719., 1104., 2235., 2681., 2510., 2354., 3555., 1900., 1616.,
#         1966.]),
#  array([ 1. ,  6.1, 11.2, 16.3, 21.4, 26.5, 31.6, 36.7, 41.8, 46.9, 52. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['housing_median_age'],15)
# Out:
# (array([ 315.,  579.,  929.,  952., 1981., 1983., 1325., 2144., 1395.,
#         1869., 2617.,  969., 1371.,  620., 1591.]),
#  array([ 1. ,  4.4,  7.8, 11.2, 14.6, 18. , 21.4, 24.8, 28.2, 31.6, 35. ,
#         38.4, 41.8, 45.2, 48.6, 52. ]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(d['housing_median_age'],20)
# Out:
# (array([ 124.,  595.,  381.,  723.,  540., 1695., 1268., 1413.,  847.,
#         1663., 1420.,  934., 1869., 1686., 1300.,  600., 1077.,  539.,
#          509., 1457.]),
#  array([ 1.  ,  3.55,  6.1 ,  8.65, 11.2 , 13.75, 16.3 , 18.85, 21.4 ,
#         23.95, 26.5 , 29.05, 31.6 , 34.15, 36.7 , 39.25, 41.8 , 44.35,
#         46.9 , 49.45, 52.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(d['total_bedrooms'],5)
# Out:
# (array([1.945e+04, 8.590e+02, 9.300e+01, 2.600e+01, 5.000e+00]),
#  array([1.0000e+00, 1.2898e+03, 2.5786e+03, 3.8674e+03, 5.1562e+03,
#         6.4450e+03]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(d['total_bedrooms'],10)
# Out:
# (array([1.5304e+04, 4.1460e+03, 6.8200e+02, 1.7700e+02, 7.0000e+01,
#         2.3000e+01, 1.8000e+01, 8.0000e+00, 3.0000e+00, 2.0000e+00]),
#  array([1.0000e+00, 6.4540e+02, 1.2898e+03, 1.9342e+03, 2.5786e+03,
#         3.2230e+03, 3.8674e+03, 4.5118e+03, 5.1562e+03, 5.8006e+03,
#         6.4450e+03]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['total_bedrooms'],15)
# Out:
# (array([1.0087e+04, 7.6920e+03, 1.6710e+03, 5.6100e+02, 1.9400e+02,
#         1.0400e+02, 5.8000e+01, 2.2000e+01, 1.3000e+01, 1.3000e+01,
#         7.0000e+00, 6.0000e+00, 3.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([1.0000e+00, 4.3060e+02, 8.6020e+02, 1.2898e+03, 1.7194e+03,
#         2.1490e+03, 2.5786e+03, 3.0082e+03, 3.4378e+03, 3.8674e+03,
#         4.2970e+03, 4.7266e+03, 5.1562e+03, 5.5858e+03, 6.0154e+03,
#         6.4450e+03]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(d['total_bedrooms'],20)
# Out:
# (array([6.165e+03, 9.139e+03, 3.100e+03, 1.046e+03, 4.660e+02, 2.160e+02,
#         1.040e+02, 7.300e+01, 4.800e+01, 2.200e+01, 1.700e+01, 6.000e+00,
#         1.300e+01, 5.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00]),
#  array([1.0000e+00, 3.2320e+02, 6.4540e+02, 9.6760e+02, 1.2898e+03,
#         1.6120e+03, 1.9342e+03, 2.2564e+03, 2.5786e+03, 2.9008e+03,
#         3.2230e+03, 3.5452e+03, 3.8674e+03, 4.1896e+03, 4.5118e+03,
#         4.8340e+03, 5.1562e+03, 5.4784e+03, 5.8006e+03, 6.1228e+03,
#         6.4450e+03]),
#  <BarContainer object of 20 artists>)
